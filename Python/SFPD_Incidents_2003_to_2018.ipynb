# %% [markdown]
# # Investigate

# %%
import pandas as pd
import os

filepath = os.path.join(os.pardir,
                        "Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv")

# %%
"""
Note that the commented out code totally works if you prefer read in the dataset from
the website instead of downloading it locally
"""
# read in file
#sfpd_2003_2018 = pd.read_csv('https://data.sfgov.org/api/views/tmnf-yvry/rows.csv')
sfpd_2003_2018 = pd.read_csv(filepath)

# %%
sfpd_2003_2018.head()
# Out:
#    IncidntNum        Category                 Descript  DayOfWeek        Date  \
# 0   146196161    NON-CRIMINAL            LOST PROPERTY    Tuesday  09/23/2014
# 1   150045675         ASSAULT                  BATTERY   Thursday  01/15/2015
# 2   140632022  SUSPICIOUS OCC  INVESTIGATIVE DETENTION  Wednesday  07/30/2014
# 3   150383259         ASSAULT                  BATTERY   Saturday  05/02/2015
# 4    40753980  OTHER OFFENSES         RECKLESS DRIVING     Friday  07/02/2004
#
#     Time PdDistrict      Resolution                   Address           X  \
# 0  01:00   SOUTHERN            NONE    800 Block of BRYANT ST -122.403405
# 1  17:00    TARAVAL            NONE  1800 Block of VICENTE ST -122.485604
# 2  09:32    BAYVIEW            NONE  100 Block of GILLETTE AV -122.396535
# 3  23:10    BAYVIEW  ARREST, BOOKED   2400 Block of PHELPS ST -122.400131
# 4  13:43    BAYVIEW            NONE   I-280 / CESAR CHAVEZ ST -120.500000
#
# ...

# %%
sfpd_2003_2018.columns
# Out:
# Index(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time',
#        'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location', 'PdId',
#        'SF Find Neighborhoods', 'Current Police Districts',
#        'Current Supervisor Districts', 'Analysis Neighborhoods',
#        'DELETE - Fire Prevention Districts', 'DELETE - Police Districts',
#        'DELETE - Supervisor Districts', 'DELETE - Zip Codes',
#        'DELETE - Neighborhoods', 'DELETE - 2017 Fix It Zones',
#        'Civic Center Harm Reduction Project Boundary',
#        'Fix It Zones as of 2017-11-06 ', 'DELETE - HSOC Zones',
#        'Fix It Zones as of 2018-02-07',
#        'CBD, BID and GBD Boundaries as of 2017',
#        'Areas of Vulnerability, 2016', 'Central Market/Tenderloin Boundary',
#        'Central Market/Tenderloin Boundary Polygon - Updated',
#        'HSOC Zones as of 2018-06-05', 'OWED Public Spaces'],
#       dtype='object')

# %%
sfpd_2003_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215024 entries, 0 to 2215023
# Data columns (total 33 columns):
#  #   Column                                                Dtype
# ---  ------                                                -----
#  0   IncidntNum                                            int64
#  1   Category                                              object
#  2   Descript                                              object
#  3   DayOfWeek                                             object
#  4   Date                                                  object
#  5   Time                                                  object
#  6   PdDistrict                                            object
#  7   Resolution                                            object
#  8   Address                                               object
#  9   X                                                     float64
# ...

# %%
# suppress scientific notation
pd.set_option('display.float_format', lambda x: '%.2f' % x)

sfpd_2003_2018.describe()
# Out:
#         IncidntNum          X          Y              PdId  \
# count   2215024.00 2215024.00 2215024.00        2215024.00
# mean  104072753.53    -122.42      37.77 10407275380402.25
# std    46128273.18       0.03       0.42  4612827317568.11
# min        3979.00    -122.51      37.71      397963010.00
# 25%    61241701.25    -122.43      37.75  6124170139093.50
# 50%   101155848.00    -122.42      37.78 10115584811503.00
# 75%   140925605.00    -122.41      37.78 14092560521910.50
# max   991582377.00    -120.50      90.00 99158237763010.00
#
#        SF Find Neighborhoods  Current Police Districts  \
# count             2208947.00                2213912.00
# mean                   52.21                      4.87
# std                    31.59                      2.78
# min                     1.00                      1.00
# 25%                    25.00                      3.00
# 50%                    44.00                      5.00
# ...

# %% [markdown]
# # Clean

# %%
# rename cols
sfpd_2003_2018 = sfpd_2003_2018.rename(columns={'X': 'Longitude',
                                               'Y': 'Latitude'})

# %%
# count missing values
sfpd_2003_2018.isna().sum()
# Out:
# IncidntNum                                                    0
# Category                                                      0
# Descript                                                      0
# DayOfWeek                                                     0
# Date                                                          0
# Time                                                          0
# PdDistrict                                                    1
# Resolution                                                    0
# Address                                                       0
# Longitude                                                     0
# Latitude                                                      0
# Location                                                      0
# PdId                                                          0
# SF Find Neighborhoods                                      6077
# Current Police Districts                                   1112
# ...

# %%
# count unique values
sfpd_2003_2018.nunique()
# Out:
# IncidntNum                                              1746914
# Category                                                     39
# Descript                                                    915
# DayOfWeek                                                     7
# Date                                                       5613
# Time                                                       1439
# PdDistrict                                                   10
# Resolution                                                   17
# Address                                                   25147
# Longitude                                                 60620
# Latitude                                                  58674
# Location                                                  61430
# PdId                                                    2215024
# SF Find Neighborhoods                                       117
# Current Police Districts                                     10
# ...

# %% [markdown]
# ### Frequency of Values
# It would be helpful to know what were the most common values for:
# * Columns showing data on reasons why police were called (Category, but Descript will yield more details)
# * Resolution (i.e., what happened after the police were called)

# %%
# Count category
sfpd_2003_2018['Category'].value_counts()
# Out:
# LARCENY/THEFT                  480448
# OTHER OFFENSES                 309358
# NON-CRIMINAL                   238323
# ASSAULT                        194694
# VEHICLE THEFT                  126602
# DRUG/NARCOTIC                  119628
# VANDALISM                      116059
# WARRANTS                       101379
# BURGLARY                        91543
# SUSPICIOUS OCC                  80444
# MISSING PERSON                  64961
# ROBBERY                         55867
# FRAUD                           41542
# SECONDARY CODES                 25831
# FORGERY/COUNTERFEITING          23050
# WEAPON LAWS                     22234
# TRESPASS                        19449
# PROSTITUTION                    16701
# STOLEN PROPERTY                 11891
# SEX OFFENSES, FORCIBLE          11742
# DISORDERLY CONDUCT              10040
# DRUNKENNESS                      9826
# RECOVERED VEHICLE                8716
# DRIVING UNDER THE INFLUENCE      5672
# KIDNAPPING                       5346
# ...

# %%
# Set option to show all rows
pd.set_option('display.max_rows', None) 


# Count unique descriptions
sfpd_2003_2018['Descript'].value_counts()
# Out:
# GRAND THEFT FROM LOCKED AUTO                                                 178836
# LOST PROPERTY                                                                 77956
# BATTERY                                                                       67654
# STOLEN AUTOMOBILE                                                             64763
# DRIVERS LICENSE, SUSPENDED OR REVOKED                                         62534
# AIDED CASE, MENTAL DISTURBED                                                  56313
# WARRANT ARREST                                                                56230
# SUSPICIOUS OCCURRENCE                                                         52490
# PETTY THEFT FROM LOCKED AUTO                                                  51946
# PETTY THEFT OF PROPERTY                                                       46114
# MALICIOUS MISCHIEF, VANDALISM                                                 45238
# ...

# %%
# Count category
sfpd_2003_2018['Resolution'].value_counts()
# Out:
# NONE                                      1389500
# ARREST, BOOKED                             524979
# ARREST, CITED                              154789
# LOCATED                                     34463
# PSYCHOPATHIC CASE                           29185
# UNFOUNDED                                   23799
# JUVENILE BOOKED                             14158
# COMPLAINANT REFUSES TO PROSECUTE             8089
# DISTRICT ATTORNEY REFUSES TO PROSECUTE       7955
# NOT PROSECUTED                               7720
# JUVENILE CITED                               6587
# PROSECUTED BY OUTSIDE AGENCY                 5070
# EXCEPTIONAL CLEARANCE                        4258
# JUVENILE ADMONISHED                          3004
# JUVENILE DIVERTED                             694
# CLEARED-CONTACT JUVENILE FOR MORE INFO        689
# PROSECUTED FOR LESSER OFFENSE                  85
# Name: Resolution, dtype: int64

# %% [markdown]
# # Which incidents were resolved?

# %%
sfpd_resolution_none = sfpd_2003_2018.loc[sfpd_2003_2018['Resolution']=='NONE']

# %%
sfpd_resolution_none['Category'].value_counts()
